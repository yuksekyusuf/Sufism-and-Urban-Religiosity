# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: openai in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (1.16.2)
# Requirement already satisfied: pandas in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (2.0.3)
# Requirement already satisfied: numpy in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: jupyter in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: pyyaml in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (6.0)
# Requirement already satisfied: transformers in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (4.32.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from openai->-r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from openai->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from openai->-r requirements.txt (line 1)) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from openai->-r requirements.txt (line 1)) (1.10.8)
# Requirement already satisfied: sniffio in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from openai->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: tqdm>4 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from openai->-r requirements.txt (line 1)) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from openai->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 2)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: notebook in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 4)) (6.5.4)
# Requirement already satisfied: qtconsole in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 4)) (5.4.2)
# Requirement already satisfied: jupyter-console in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 4)) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 4)) (6.5.4)
# Requirement already satisfied: ipykernel in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 4)) (6.25.0)
# Requirement already satisfied: ipywidgets in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jupyter->-r requirements.txt (line 4)) (8.0.4)
# Requirement already satisfied: filelock in /Users/ahmetyusufyuksek/.local/lib/python3.11/site-packages (from transformers->-r requirements.txt (line 6)) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from transformers->-r requirements.txt (line 6)) (0.15.1)
# Requirement already satisfied: packaging>=20.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from transformers->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from transformers->-r requirements.txt (line 6)) (2022.7.9)
# Requirement already satisfied: requests in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from transformers->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from transformers->-r requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from transformers->-r requirements.txt (line 6)) (0.3.2)
# Requirement already satisfied: idna>=2.8 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: certifi in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: fsspec in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers->-r requirements.txt (line 6)) (2023.4.0)
# Requirement already satisfied: six>=1.5 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: appnope in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (8.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (1.5.6)
# Requirement already satisfied: psutil in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipykernel->jupyter->-r requirements.txt (line 4)) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 4)) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 4)) (3.0.5)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 4)) (3.0.36)
# Requirement already satisfied: pygments in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 4)) (2.15.1)
# Requirement already satisfied: lxml in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: bleach in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: defusedxml in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (0.4)
# Requirement already satisfied: jinja2>=3.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->-r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: argon2-cffi in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 4)) (21.3.0)
# Requirement already satisfied: ipython-genutils in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 4)) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 4)) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->-r requirements.txt (line 4)) (0.5.5)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from qtconsole->jupyter->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ahmetyusufyuksek/.local/lib/python3.11/site-packages (from requests->transformers->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from requests->transformers->-r requirements.txt (line 6)) (1.26.16)
# Requirement already satisfied: backcall in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: decorator in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 4)) (0.7.5)
# Requirement already satisfied: stack-data in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 4)) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r requirements.txt (line 4)) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: fastjsonschema in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert->jupyter->-r requirements.txt (line 4)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert->jupyter->-r requirements.txt (line 4)) (4.17.3)
# Requirement already satisfied: wcwidth in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 4)) (0.2.5)
# Requirement already satisfied: ptyprocess in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from terminado>=0.8.3->notebook->jupyter->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from argon2-cffi->notebook->jupyter->-r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 4)) (2.4)
# Requirement already satisfied: webencodings in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from bleach->nbconvert->jupyter->-r requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 4)) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r requirements.txt (line 4)) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r requirements.txt (line 4)) (0.18.0)
# Requirement already satisfied: websocket-client in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r requirements.txt (line 4)) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r requirements.txt (line 4)) (1.15.1)
# Requirement already satisfied: executing in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 4)) (0.8.3)
# Requirement already satisfied: asttokens in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 4)) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: pycparser in /Users/ahmetyusufyuksek/anaconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r requirements.txt (line 4)) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from scripts.ner_automation import *
from utils.openai_client import client

# %%
file_path = 'data/raw.csv'
df = pd.read_csv(file_path)
df['case_text_summary'] = "Summary: " + df['case_summary'].astype(str) + "\n" + "Case: " + df['case_text'].astype(str)

# %%
df.head()
# Out:
#    Unnamed: 0 court_title sicil_number                   sicil_date  \
# 0           0      Adalar            1  H. 1178-1184 / M. 1764-1771
# 1           1      Adalar            1  H. 1178-1184 / M. 1764-1771
# 2           2      Adalar            1  H. 1178-1184 / M. 1764-1771
# 3           3      Adalar            1  H. 1178-1184 / M. 1764-1771
# 4           4      Adalar            1  H. 1178-1184 / M. 1764-1771
#
#       date_hijri    date_miladi  \
# 0  H. 1178-1184    M. 1764-1771
# 1  H. 1178-1184    M. 1764-1771
# 2  H. 1178-1184    M. 1764-1771
# 3  H. 1178-1184    M. 1764-1771
# 4  H. 1178-1184    M. 1764-1771
#
#                                            case_text  \
# 0  ['[İç Kapak]', 'Mûcebince amel oluna deyü buyr...
# 1  ['Kasab Veli Beşe kanadârı Mumço? nâm zimmîye ...
# 2  ['Bundan akdem hâlik olan Esteban v. Kirkor v....
# 3  ['Culûs-ı Sultân Mustafa Han b. es-Sultân Abdü...
# 4  ['Devletlü inâyetlü merhametlü efendim sultânı...
#
#                                         case_summary  case_number  id  \
# 0                       117[8] ilâ 1184 Adalar Hücec   Hüküm no:    1
# 1               Kasap Veli’nin Mumço’ya kefil olduğu  Hüküm no: 1   2
# 2  Ölen Esteban’ın terekesinin varislerine taksim...  Hüküm no: 2   3
# 3  Sultan Mustafa Han’ın tahta çıkış tarihinin no...  Hüküm no: 3   4
# 4                      Yarım kalan bir arzuhal kaydı  Hüküm no: 4   5
#
#                                    case_text_summary
# 0  Summary: 117[8] ilâ 1184 Adalar Hücec\nCase: [...
# 1  Summary: Kasap Veli’nin Mumço’ya kefil olduğu\...
# 2  Summary: Ölen Esteban’ın terekesinin varisleri...
# 3  Summary: Sultan Mustafa Han’ın tahta çıkış tar...
# 4  Summary: Yarım kalan bir arzuhal kaydı\nCase: ...

# %% [markdown]
# İsam Veri Tabanından çekilen verilerin kısaca değerlendirilmesi

# %%
# Farklı mahkeme sayısı
num_courts = df['court_title'].nunique()

# Her mahkeme için sicil sayısı (court_title ve sicil_number birleştirilerek)
registers_per_court = df.groupby('court_title')['sicil_number'].nunique()

# Her mahkeme için dava girişlerinin sayısı
case_entries_per_court = df.groupby('court_title').size()

# Toplam dava sayısı
total_cases = case_entries_per_court.sum()

# Sonuçları göster
print(f"Farklı mahkeme sayısı: {num_courts}")
print("Her mahkeme için sicil sayısı:")
print(registers_per_court)
print("Her mahkeme için dava girişlerinin sayısı:")
print(case_entries_per_court)
print(f"Toplam dava sayısı: {total_cases}")
total_registers = registers_per_court.sum()
print(f"Toplam sicil sayısı: {total_registers}")
# Out:
# Farklı mahkeme sayısı: 22
# Her mahkeme için sicil sayısı:
# court_title
# Adalar                 1
# Ahi Çelebi             1
# Anadolu Sadareti       1
# Anadolu Sadâreti       1
# Bab                   10
# Balat                  2
# Beşiktaş               2
# Davud Paşa             1
# Evkaf Mahkemesi        1
# Evkaf Muhasebesi       1
# Evkaf Müfettişliği     1
# Eyüp                  11
# Galata                12
# Hasköy                 3
# Kartal                 1
# Kısmet-i Askeriye      2
# Mahfel-i Şer‘iyyât     1
# Mahmudpaşa             1
# Rumeli Sadareti        8
# Tophane                1
# Üsküdar               13
# İstanbul              24
# Name: sicil_number, dtype: int64
# Her mahkeme için dava girişlerinin sayısı:
# court_title
# Adalar                  183
# Ahi Çelebi              534
# Anadolu Sadareti        185
# Anadolu Sadâreti        254
# Bab                    7245
# Balat                  1115
# Beşiktaş               1027
# Davud Paşa              788
# Evkaf Mahkemesi         239
# Evkaf Muhasebesi         82
# Evkaf Müfettişliği      586
# Eyüp                   5580
# Galata                 4895
# Hasköy                 1190
# Kartal                  491
# Kısmet-i Askeriye      1293
# Mahfel-i Şer‘iyyât      143
# Mahmudpaşa              572
# Rumeli Sadareti        3787
# Tophane                 894
# Üsküdar               11038
# İstanbul              12348
# dtype: int64
# Toplam dava sayısı: 54469
# Toplam sicil sayısı: 99

# %% [markdown]
# Görüldüğü gibi mahkeme isimleri arasında bir takım tutarsızlıklar. Alttaki kod bu tutarsızlıkları düzeltmek için.

# %%
# Perform the specified changes in the DataFrame
df.loc[df['court_title'] == 'Evkaf Muhasebesi1', 'court_title'] = 'Evkaf Muhasebesi'
df.loc[df['court_title'] == 'Eyüb', 'court_title'] = 'Eyüp'
df.loc[df['court_title'] == 'Rumeli Sadâreti', 'court_title'] = 'Rumeli Sadareti'
df.loc[df['court_title'] == 'Evkaf-ı Hümâyûn', 'court_title'] = 'Evkaf Mahkemesi'
df.loc[df['court_title'] == 'Evkaf-ı HümâyûnMüfettişliği', 'court_title'] = 'Evkaf Müfettişliği'

df.loc[df['court_title'] == 'Evkaf Müfettişliği', 'sicil_number'] = '1'
df.loc[df['court_title'] == 'Evkaf Muhasebesi', 'sicil_number'] = '1'
df.loc[df['court_title'] == 'Evkaf Mahkemesi', 'sicil_number'] = '673'

# %%
most_cases = df.loc[df['court_title'] == case_entries_per_court.idxmax(), ['court_title', 'sicil_number']].iloc[0]
least_cases = df.loc[df['court_title'] == case_entries_per_court.idxmin(), ['court_title', 'sicil_number']].iloc[0]

print(f"En fazla dava sayısı olan defter: {most_cases['court_title']} sicil numarası {most_cases['sicil_number']} ({case_entries_per_court.max()} dava)")
print(f"En az dava sayısı olan defter: {least_cases['court_title']} sicil numarası {least_cases['sicil_number']} ({case_entries_per_court.min()} dava)")
# Out:
# En fazla dava sayısı olan defter: İstanbul sicil numarası 3 (12348 dava)
# En az dava sayısı olan defter: Evkaf Muhasebesi sicil numarası 1 (82 dava)

# %%
import matplotlib.pyplot as plt

# date_miladi sütununu düzenleyin ve sadece yılı alın
df['year'] = df['date_miladi'].str.extract(r'M\. (\d{4})').astype(float)

# NaN değerlerini kaldırın
df = df.dropna(subset=['year'])

# Yıllık bazda dava sayısını hesaplayın
yearly_case_counts = df['year'].value_counts().sort_index()

# Yıllık dava dağılımını gösteren bir grafik oluşturun
plt.figure(figsize=(10, 6))
plt.plot(yearly_case_counts.index, yearly_case_counts.values, marker='o', linestyle='-')
plt.title('Yıllık Dava Dağılımı')
plt.xlabel('Yıl')
plt.ylabel('Dava Sayısı')
plt.grid(True)
plt.show()

# %%
# date_miladi sütununu düzenleyin ve sadece yılı alın
df['year'] = df['date_miladi'].str.extract(r'M\. (\d{4})').astype(float)

# NaN değerlerini kaldırın
df = df.dropna(subset=['year'])

# Yıllık bazda toplam sicil sayısını hesaplayın
yearly_register_counts = df.groupby('year')['sicil_number'].nunique()

# Yıllık sicil dağılımını gösteren bir sütun grafiği oluşturun
plt.figure(figsize=(15, 8))
yearly_register_counts.plot(kind='bar')
plt.title('Yıllık Sicil Dağılımı')
plt.xlabel('Yıl')
plt.ylabel('Sicil Sayısı')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# date_miladi sütununu düzenleyin ve sadece yılı alın
df['year'] = df['date_miladi'].str.extract(r'M\. (\d{4})').astype(float)

# NaN değerlerini kaldırın
df = df.dropna(subset=['year'])

# Yılları 1500'den itibaren 25 yıllık aralıklara ayırın
bins = range(1500, int(df['year'].max()) + 25, 25)
labels = [f"{start}-{start+24}" for start in bins[:-1]]
df['period'] = pd.cut(df['year'], bins=bins, labels=labels, right=False)

# 25 yıllık dönemler için toplam sicil sayısını hesaplayın
periodic_register_counts = df.groupby('period')['sicil_number'].nunique()

# 25 yıllık dönemlerin sicil dağılımını gösteren bir sütun grafiği oluşturun
plt.figure(figsize=(15, 8))
periodic_register_counts.plot(kind='bar')
plt.title('25 Yıllık Dönemler İçin Sicil Dağılımı (1500\'den itibaren)')
plt.xlabel('Dönem')
plt.ylabel('Sicil Sayısı')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# date_miladi sütununu düzenleyin ve sadece yılı alın
df['year'] = df['date_miladi'].str.extract(r'M\. (\d{4})').astype(float)

# NaN değerlerini kaldırın
df = df.dropna(subset=['year'])

# Yılları 1500'den itibaren 25 yıllık aralıklara ayırın
bins = range(1500, int(df['year'].max()) + 25, 25)
labels = [f"{start}-{start+24}" for start in bins[:-1]]
df['period'] = pd.cut(df['year'], bins=bins, labels=labels, right=False)

# 25 yıllık dönemler için toplam sicil sayısını hesaplayın
periodic_register_counts = df.groupby('period')['sicil_number'].nunique()

# 25 yıllık dönemler için toplam dava sayısını hesaplayın
periodic_case_counts = df['period'].value_counts().sort_index()

# 25 yıllık dönemlerin sicil ve dava dağılımını gösteren bir sütun grafiği oluşturun
fig, ax1 = plt.subplots(figsize=(15, 8))

# Sicil sayılarını bar grafiği olarak göster
ax1.bar(periodic_register_counts.index, periodic_register_counts.values, color='b', alpha=0.6, label='Sicil Sayısı')
ax1.set_xlabel('Dönem')
ax1.set_ylabel('Sicil Sayısı', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Aynı grafikte dava sayılarını da göstermek için ikinci bir y ekseni oluştur
ax2 = ax1.twinx()
ax2.plot(periodic_case_counts.index, periodic_case_counts.values, color='r', marker='o', linestyle='-', label='Dava Sayısı')
ax2.set_ylabel('Dava Sayısı', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Başlık ve grid ekle
plt.title('25 Yıllık Dönemler İçin Sicil ve Dava Dağılımı (1500\'den itibaren)')
ax1.grid(axis='y')

# Grafik üzerine legend ekle
fig.legend(loc='upper left', bbox_to_anchor=(0.1,0.9))

plt.tight_layout()
plt.show()

# %% [markdown]
# Görüldüğü üzere en fazla defterin ve kaydın bulunduğu aralık 1650-75 tarihleri arası. GPT destekli analizim için bu tarih aralığından bir defter örneği seçmek istiyorum.

# %%
# Filter the dataframe for the period 1650-1675
df_filtered = df[(df['year'] >= 1650) & (df['year'] < 1676)]

# Select unique court titles and their sicil numbers within this period
registers_1650_1675 = df_filtered[['court_title', 'sicil_number']].drop_duplicates().reset_index(drop=True)

# %%
registers_1650_1675
# Out:
#         court_title sicil_number
# 0        Ahi Çelebi            1
# 1               Bab            3
# 2               Bab           11
# 3          Beşiktaş           63
# 4              Eyüp            7
# 5              Eyüp            8
# 6            Galata           90
# 7            Galata          114
# 8            Hasköy           10
# 9          İstanbul           10
# 10         İstanbul           12
# 11         İstanbul           18
# 12  Rumeli Sadareti          106

# %%
# Filter the dataframe for the specified court and sicil number
istanbul_10_cases = df[(df['court_title'] == 'İstanbul') & (df['sicil_number'] == '10')]

# Count the total number of case entries in this register
total_cases_istanbul_10 = istanbul_10_cases.shape[0]

total_cases_istanbul_10
print(f"İstanbul 10 numaralı defterdeki toplam dava kaydı: {total_cases_istanbul_10}")
# Out:
# İstanbul 10 numaralı defterdeki toplam dava kaydı: 1123

# %%
court_sicil_list = [
    ('Ahi Çelebi', '1'),
    ('Bab', '3'),
    ('Bab', '11'),
    ('Beşiktaş', '63'),
    ('Eyüp', '7'),
    ('Eyüp', '8'),
    ('Galata', '90'),
    ('Galata', '114'),
    ('Hasköy', '10'),
    ('İstanbul', '10'),
    ('İstanbul', '12'),
    ('İstanbul', '18'),
    ('Rumeli Sadareti', '106')
]

# Filtrelenmiş veriyi oluşturun
filtered_df = df[df.apply(lambda x: (x['court_title'], x['sicil_number']) in court_sicil_list, axis=1)]

# Her mahkeme ve sicil numarası için dava sayılarını hesaplayın
case_counts = filtered_df.groupby(['court_title', 'sicil_number']).size().reset_index(name='case_count')

# Mahkeme ve sicil numaralarını birleştirerek etiketler oluşturun
case_counts['label'] = case_counts['court_title'] + ' ' + case_counts['sicil_number']

# Ortalama dava sayısını hesaplayın
average_case_count = case_counts['case_count'].mean()

# Grafik oluşturun
plt.figure(figsize=(15, 8))
plt.bar(case_counts['label'], case_counts['case_count'], color='b', alpha=0.6, label='Dava Sayısı')
plt.axhline(y=average_case_count, color='r', linestyle='--', label=f'Ortalama Dava Sayısı: {average_case_count:.2f}')
plt.xlabel('Mahkeme ve Sicil Numarası')
plt.ylabel('Dava Sayısı')
plt.title('Mahkeme ve Sicil Numaralarına Göre Dava Sayıları')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y')
plt.legend()

plt.show()

# %% [markdown]
# İstanbul 18 numaralı defter en uygunu gözüküyor. Şimdi bu defter üzerinden örneklem olarak bir Named Entity Recognition (NER) görevi gerçekleştireceğiz.

# %%
df_copy = df.copy()
df_copy['case_id'] = (df_copy['court_title'] + '_' + 
                      df_copy['sicil_number'].astype(str) + '_' + 
                      df_copy['case_number']).str.lower()

# %%
# İstanbul 18 sicil defteri için veri süzme
istanbul_18_df = df_copy[(df_copy['court_title'] == 'İstanbul') & (df_copy['sicil_number'] == '18')]

# NER görevini gerçekleştirmek ve sonuçları bir dosyaya kaydetmek için dosya yolu belirleme
output_file = 'ner_results_istanbul18.csv'

# NER fonksiyonunu çağırma
process_dataframe_ner(istanbul_18_df, 'case_text_summary', 'court_title', 'case_id', output_file)
# Out:
# An error occured: '[' was never closed (<string>, line 427)
# Error processing row 27135: '[' was never closed (<string>, line 427)
# An error occured: unterminated string literal (detected at line 487) (<string>, line 487)
# Error processing row 27229: unterminated string literal (detected at line 487) (<string>, line 487)
# An error occured: unterminated string literal (detected at line 482) (<string>, line 482)
# Error processing row 27230: unterminated string literal (detected at line 482) (<string>, line 482)
#                                     person_id               name gender  \
# 0      İstanbul_i̇stanbul_18_hüküm no: kapa_1  Beyâzîzâde Efendi    Man
# 1                                         NaN                NaN    NaN
# 2                                         NaN                NaN    NaN
# 3                                         NaN                NaN    NaN
# 4                                         NaN                NaN    NaN
# ...                                       ...                ...    ...
# 13747                                     NaN                NaN    NaN
# 13748                                     NaN                NaN    NaN
# 13749                                     NaN                NaN    NaN
# 13750                                     NaN                NaN    NaN
# 13751                                     NaN                NaN    NaN
#
#       religion_ethnicity social_status_job role_in_case    titles  row_index  \
# 0                 Muslim               N/A     Deceased  [Efendi]      27133
# 1                    NaN               NaN          NaN       NaN      27133
# 2                    NaN               NaN          NaN       NaN      27133
# 3                    NaN               NaN          NaN       NaN      27133
# 4                    NaN               NaN          NaN       NaN      27133
# ...                  ...               ...          ...       ...        ...
# 13747                NaN               NaN          NaN       NaN      27822
# 13748                NaN               NaN          NaN       NaN      27822
# 13749                NaN               NaN          NaN       NaN      27822
# 13750                NaN               NaN          NaN       NaN      27822
# 13751                NaN               NaN          NaN       NaN      27822
#
#                     case_unique_id  date calendar place_name place_type  \
# 0      i̇stanbul_18_hüküm no: kapa   NaN      NaN        NaN        NaN
# 1      i̇stanbul_18_hüküm no: kapa  1086    Hijri        NaN        NaN
# 2      i̇stanbul_18_hüküm no: kapa  1087    Hijri        NaN        NaN
# 3      i̇stanbul_18_hüküm no: kapa  1675   Miladi        NaN        NaN
# 4      i̇stanbul_18_hüküm no: kapa  1676   Miladi        NaN        NaN
# ...                            ...   ...      ...        ...        ...
# 13747   i̇stanbul_18_hüküm no: 689   N/A   Miladi        NaN        NaN
# 13748   i̇stanbul_18_hüküm no: 689   NaN      NaN   İstanbul       city
# 13749   i̇stanbul_18_hüküm no: 689   NaN      NaN        NaN        NaN
# 13750   i̇stanbul_18_hüküm no: 689   NaN      NaN        NaN        NaN
# 13751   i̇stanbul_18_hüküm no: 689   NaN      NaN        NaN        NaN
#
#          legal_case_type case_result case_result_type
# 0                    NaN         NaN              NaN
# 1                    NaN         NaN              NaN
# 2                    NaN         NaN              NaN
# 3                    NaN         NaN              NaN
# 4                    NaN         NaN              NaN
# ...                  ...         ...              ...
# 13747                NaN         NaN              NaN
# 13748                NaN         NaN              NaN
# 13749  Property Disputes         NaN              NaN
# 13750                NaN         N/A              NaN
# 13751                NaN         NaN              N/A
#
# [13752 rows x 16 columns]

# %%
ner_df
# Out:
#                               person_id                       name gender  \
# 0   İstanbul_i̇stanbul_18_hüküm no: 6_1    Süleyman b. Kör Ali Ağa    Man
# 1   İstanbul_i̇stanbul_18_hüküm no: 6_2                Kör Ali Ağa    Man
# 2   İstanbul_i̇stanbul_18_hüküm no: 6_3       Hüseyin Ağa b. Receb    Man
# 3   İstanbul_i̇stanbul_18_hüküm no: 6_4       Hasan Beşe b. Mehmed    Man
# 4   İstanbul_i̇stanbul_18_hüküm no: 6_5  Kalender b. Mehmed Çelebi    Man
# ..                                  ...                        ...    ...
# 66                                  NaN                        NaN    NaN
# 67                                  NaN                        NaN    NaN
# 68                                  NaN                        NaN    NaN
# 69                                  NaN                        NaN    NaN
# 70                                  NaN                        NaN    NaN
#
#    religion_ethnicity        social_status_job                 role_in_case  \
# 0              Muslim                      N/A                    Plaintiff
# 1              Muslim                      N/A              Deceased Father
# 2              Muslim  Janissary Beytülmâlcisi                    Defendant
# 3              Muslim                      N/A         Guardian of Süleyman
# 4              Muslim                      N/A  Former Guardian of Süleyman
# ..                ...                      ...                          ...
# 66                NaN                      NaN                          NaN
# 67                NaN                      NaN                          NaN
# 68                NaN                      NaN                          NaN
# 69                NaN                      NaN                          NaN
# 70                NaN                      NaN                          NaN
#
#       titles  row_index            case_unique_id date calendar  \
# 0         []      27139  i̇stanbul_18_hüküm no: 6  NaN      NaN
# 1      [Ağa]      27139  i̇stanbul_18_hüküm no: 6  NaN      NaN
# 2      [Ağa]      27139  i̇stanbul_18_hüküm no: 6  NaN      NaN
# 3     [Beşe]      27139  i̇stanbul_18_hüküm no: 6  NaN      NaN
# 4   [Çelebi]      27139  i̇stanbul_18_hüküm no: 6  NaN      NaN
# ..       ...        ...                       ...  ...      ...
# 66       NaN      27140  i̇stanbul_18_hüküm no: 7  NaN      NaN
# 67       NaN      27140  i̇stanbul_18_hüküm no: 7  NaN      NaN
# 68       NaN      27140  i̇stanbul_18_hüküm no: 7  NaN      NaN
# 69       NaN      27140  i̇stanbul_18_hüküm no: 7  NaN      NaN
# 70       NaN      27140  i̇stanbul_18_hüküm no: 7  NaN      NaN
#
#                        place_name place_type              legal_case_type  \
# 0                             NaN        NaN                          NaN
# 1                             NaN        NaN                          NaN
# 2                             NaN        NaN                          NaN
# 3                             NaN        NaN                          NaN
# 4                             NaN        NaN                          NaN
# ..                            ...        ...                          ...
# 66                      Şehremini     region                          NaN
# 67  Mustafa Çavuş mescid-i şerîfi     mosque                          NaN
# 68                            NaN        NaN  Religious Endowments (Waqf)
# 69                            NaN        NaN                          NaN
# 70                            NaN        NaN                          NaN
#
#                                           case_result   case_result_type
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# ..                                                ...                ...
# 66                                                NaN                NaN
# 67                                                NaN                NaN
# 68                                                NaN                NaN
# 69  Ali Çelebi is ordered to pay 351 guruş to the ...                NaN
# 70                                                NaN  Trial by evidence
#
# [71 rows x 16 columns]

# %%
istanbul18 = pd.read_csv('ner_results_istanbul18.csv')

# %%
istanbul18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13752 entries, 0 to 13751
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   person_id           8113 non-null   object
#  1   name                8113 non-null   object
#  2   gender              8112 non-null   object
#  3   religion_ethnicity  8092 non-null   object
#  4   social_status_job   1348 non-null   object
#  5   role_in_case        7941 non-null   object
#  6   titles              8113 non-null   object
#  7   date                1418 non-null   object
#  8   calendar            1434 non-null   object
#  9   place_name          2143 non-null   object
#  10  place_type          2130 non-null   object
#  11  legal_case_type     685 non-null    object
#  12  case_result         644 non-null    object
#  13  case_result_type    644 non-null    object
#  14  row_index           13752 non-null  int64
#  15  case_unique_id      13752 non-null  object
# dtypes: int64(1), object(15)
# memory usage: 1.7+ MB

# %%
# Temel istatistikleri görüntüleyin
istanbul18.describe(include='all')
# Out:
#                                      person_id                     name  \
# count                                     8113                     8113
# unique                                    8113                     4433
# top     İstanbul_i̇stanbul_18_hüküm no: kapa_1  İbrahim Çelebi b. Ahmed
# freq                                         1                      155
# mean                                       NaN                      NaN
# std                                        NaN                      NaN
# min                                        NaN                      NaN
# 25%                                        NaN                      NaN
# 50%                                        NaN                      NaN
# 75%                                        NaN                      NaN
# max                                        NaN                      NaN
#
#        gender religion_ethnicity social_status_job role_in_case titles  \
# count    8112               8092              1348         7941   8113
# unique      2                 15                89          214    523
# top       Man             Muslim        Bureaucrat      Witness     []
# freq     7381               7571               313         5548   2570
# mean      NaN                NaN               NaN          NaN    NaN
# std       NaN                NaN               NaN          NaN    NaN
# min       NaN                NaN               NaN          NaN    NaN
# 25%       NaN                NaN               NaN          NaN    NaN
# 50%       NaN                NaN               NaN          NaN    NaN
# 75%       NaN                NaN               NaN          NaN    NaN
# max       NaN                NaN               NaN          NaN    NaN
#
#             date calendar place_name    place_type       legal_case_type  \
# count       1418     1434       2143          2130                   685
# unique       499        2       1044            88                    17
# top     May 1676    Hijri   İstanbul  neighborhood  Debt/Loan Agreements
# freq          23      717        221           597                   193
# mean         NaN      NaN        NaN           NaN                   NaN
# std          NaN      NaN        NaN           NaN                   NaN
# min          NaN      NaN        NaN           NaN                   NaN
# 25%          NaN      NaN        NaN           NaN                   NaN
# 50%          NaN      NaN        NaN           NaN                   NaN
# 75%          NaN      NaN        NaN           NaN                   NaN
# max          NaN      NaN        NaN           NaN                   NaN
#
#        case_result case_result_type     row_index              case_unique_id
# count          644              644  13752.000000                       13752
# unique         484               10           NaN                         687
# top     Settlement       Settlement           NaN  i̇stanbul_18_hüküm no: 497
# freq            92              460           NaN                          54
# mean           NaN              NaN  27475.887725                         NaN
# std            NaN              NaN    198.778679                         NaN
# min            NaN              NaN  27133.000000                         NaN
# 25%            NaN              NaN  27305.000000                         NaN
# 50%            NaN              NaN  27472.000000                         NaN
# 75%            NaN              NaN  27651.000000                         NaN
# max            NaN              NaN  27822.000000                         NaN

# %% [markdown]
# ### Cinsiyet

# %%
istanbul18['gender'].value_counts()
# Out:
# gender
# Man      7381
# Woman     731
# Name: count, dtype: int64

# %% [markdown]
# ### Din

# %%
istanbul18['religion_ethnicity'].value_counts()
# Out:
# religion_ethnicity
# Muslim                         7571
# Greek                           247
# Armenian                        139
# Christian                        46
# Jewish                           30
# Russian                          26
# European                         13
# Non-Muslim                       12
# European (Hungarian)              2
# Circassian                        1
# Habeş (Abyssinian)                1
# Muslim (originally Russian)       1
# Coptic                            1
# Hungarian                         1
# Muslim, Georgian                  1
# Name: count, dtype: int64

# %% [markdown]
# ### Dava

# %%
istanbul18['legal_case_type'].value_counts()
# Out:
# legal_case_type
# Debt/Loan Agreements            193
# Property Disputes               176
# Marital Disputes                109
# Inheritance Cases                89
# Slavery and Manumission          48
# Religious Endowments (Waqf)      19
# Trade Disputes                   16
# Criminal Cases                   14
# Appointments                      5
# Taxation Disputes                 4
# Guardianship Appointment          3
# Employment Disputes               2
# Pilgrimage Arrangements           2
# Adoption                          2
# Contract Disputes                 1
# Appointment                       1
# Guardianship and Maintenance      1
# Name: count, dtype: int64

# %%
# Sosyal durum/iş rolleri dağılımı
social_status_counts = istanbul18['social_status_job'].value_counts()
# Çıktıda görüntülenebilecek maksimum satır sayısını artırın
pd.set_option('display.max_rows', None)

# Sosyal sınıfsal kategorileri ve dağılımlarını yeniden görüntüleyin
print(social_status_counts)
# Out:
# social_status_job
# Bureaucrat                                      313
# Scholar/Ulama                                   201
# Trader/Merchant                                 197
# Artisan/Craftsperson                            119
# Müezzin                                         111
# Imam                                             82
# Janissary                                        64
# Slave/Enslaved Person                            56
# Religious Leader                                 36
# Sufi                                             11
# Kethüdâ                                          10
# Barber                                            9
# Pilgrim                                           7
# İmam                                              7
# Physician/Healer                                  6
# Sipahi                                            6
# Treasurer                                         6
# İmâm                                              6
# Kayyım                                            5
# Crafts Guild Member                               5
# Muezzin                                           4
# Judge                                             4
# Scholar                                           4
# Seafarer                                          3
# Scribe                                            3
# Gardener                                          3
# Mübâşir                                           2
# Sarrâc                                            2
# Tax Collector                                     2
# Bathhouse Attendant                               2
# Tailor                                            2
# Former Judge                                      2
# Odabaşı                                           2
# Crafts Guild Member (Carpenter)                   1
# Müteferrika                                       1
# Jeweler                                           1
# Former Bosnian Judge                              1
# Bostancı                                          1
# Town Crier                                        1
# Davud Paşa mütevellîsi                            1
# Kazzâz (Silk Weaver)                              1
# Former Judge of Medina                            1
# Kâtib-i Vakf-ı Kılıç Ali Paşa                     1
# Bureaucrat (Former Judge)                         1
# Janissary Ağa                                     1
# Slave Trader                                      1
# Slave/Enslaved Person (Freed)                     1
# Sufi Leader                                       1
# Servant                                           1
# Former Mütesellim                                 1
# Mübaşir                                           1
# Müezzin and Kayyım                                1
# Religious Official                                1
# Reis                                              1
# Kapudan                                           1
# Başkorucu                                         1
# Vakf Trustee                                      1
# Subaşı (Chief of Police)                          1
# Baker                                             1
# Müneccimbaşı (Chief Astrologer)                   1
# Butcher                                           1
# Derviş                                            1
# Nâibü’ş-şer‘                                      1
# Saddler                                           1
# Bookbinder                                        1
# Bathhouse Keeper                                  1
# Water Carrier                                     1
# Cotton Carder                                     1
# Musketeer                                         1
# Perfumer                                          1
# Cebeci                                            1
# Translator                                        1
# Farmer/Agriculturist                              1
# Artisan/Craftsperson (Grocer)                     1
# Porter                                            1
# Artisan/Craftsperson (Perfumer)                   1
# Kethüdâ-yı muhzırân                               1
# Religious Leader (Former Armenian Patriarch)      1
# Asesbaşı (Chief of Night Watchmen)                1
# Former Judge of Damascus                          1
# Dellâl                                            1
# Şeyh                                              1
# Tinsmith                                          1
# Nâib (Deputy)                                     1
# Hamamcılar Kethüdâsı                              1
# Kadı                                              1
# Bakkal (Grocer)                                   1
# Çorbacı                                           1
# Cleric                                            1
# Name: count, dtype: int64

# %%
# Dava sonuçları dağılımı
case_result_counts = istanbul18['case_result'].value_counts()
case_result_counts
# Out:
# case_result
# Settlement                                                                         92
# Plaintiff won                                                                      31
# Divorce granted                                                                    10
# Sale completed                                                                      6
# Plaintiffs won                                                                      5
#                                                                                    ..
# Emine bt. İbrahim acknowledged her debt and agreed to pay the remaining amount.     1
# Settlement in favor of Ayşe and Kâmile                                              1
# Nazar v. Parsık won the case                                                        1
# Settlement in favor of Ayşe bt. Musa                                                1
# Hasan Odabaşı b. Hüseyin won the case                                               1
# Name: count, Length: 484, dtype: int64

# %%
# Dava sonuç türleri dağılımı
case_result_type_counts = istanbul18['case_result_type'].value_counts()
case_result_type_counts
# Out:
# case_result_type
# Settlement                   460
# Trial by evidence            101
# Resolution by oath            63
# trial by evidence              6
# settlement                     5
# muhâla‘a                       3
# Resolution by appointment      2
# Resolution by decree           2
# resolution by oath             1
# Appointment                    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Jupyter Notebook'ta grafiklerin otomatik olarak gösterilmesi için
# %matplotlib inline

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=istanbul18, x='social_status_job')
plt.xticks(rotation=90)
plt.title('Sosyal Durum/İş Rolleri Dağılımı')
plt.show()

# %%
# Din dağılımı grafiği
plt.figure(figsize=(10, 6))
sns.barplot(x=religion_counts.index, y=religion_counts.values, palette='viridis')
plt.xlabel('Din/Etnik Köken')
plt.ylabel('Dava Sayısı')
plt.title('İstanbul 18 Sicil Kaydına Göre Din Dağılımı')
plt.xticks(rotation=45)
plt.show()

# %%
# Şahitleri filtreleyin
witnesses = istanbul18[istanbul18['role_in_case'] == 'Witness']
# Şahitlerin dini dağılımını hesaplayın
witness_religion_counts = witnesses['religion_ethnicity'].value_counts()
witness_religion_counts
# Jupyter Notebook'ta grafiklerin otomatik olarak gösterilmesi için
# %matplotlib inline

# Şahitlerin dini dağılımı grafiği
plt.figure(figsize=(10, 6))
sns.barplot(x=witness_religion_counts.index, y=witness_religion_counts.values, palette='viridis')
plt.xlabel('Din/Etnik Köken')
plt.ylabel('Şahit Sayısı')
plt.title('İstanbul 18 Sicil Kaydına Göre Şahitlerin Din Dağılımı')
plt.xticks(rotation=45)
plt.show()

# %%
# Sufi unvanlarını belirleyin
sufi_titles = ['Şeyh', 'Derviş', 'Dede', 'Baba', 'Mevlevi', 'Bektaşi', 'Nakşibendi', 'Halveti', 'Sufi', 'Sufi leader']

# Sufileri filtreleyin
sufis = istanbul18[istanbul18['titles'].apply(lambda titles: any(title in titles for title in sufi_titles))]

# Sufilerin dahil oldukları dava türlerini hesaplayın
sufi_case_types = sufis['legal_case_type'].value_counts()
sufi_case_types

# Sufilerin dahil oldukları dava türleri grafiği
plt.figure(figsize=(10, 6))
sns.barplot(x=sufi_case_types.index, y=sufi_case_types.values, palette='viridis')
plt.xlabel('Dava Türü')
plt.ylabel('Sufi Sayısı')
plt.title('İstanbul 18 Sicil Kaydına Göre Sufilerin Dahil Oldukları Dava Türleri')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       2 sufi_titles = ['Şeyh', 'Derviş', 'dede', 'baba', 'mevlevi', 'bektaşi', 'nakşibendi', 'halveti', 'Sufi', 'Sufi leader']
#       4 # Sufileri filtreleyin
# ----> 5 sufis = istanbul18[istanbul18['titles'].apply(lambda titles: any(title in titles for title in sufi_titles))]
#       7 # Sufilerin dahil oldukları dava türlerini hesaplayın
#       8 sufi_case_types = sufis['legal_case_type'].value_counts()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[34], line 5, in <lambda>(titles)
#       2 sufi_titles = ['Şeyh', 'Derviş', 'dede', 'baba', 'mevlevi', 'bektaşi', 'nakşibendi', 'halveti', 'Sufi', 'Sufi leader']
#       4 # Sufileri filtreleyin
# ----> 5 sufis = istanbul18[istanbul18['titles'].apply(lambda titles: any(title in titles for title in sufi_titles))]
#       7 # Sufilerin dahil oldukları dava türlerini hesaplayın
#       8 sufi_case_types = sufis['legal_case_type'].value_counts()
#
# Cell In[34], line 5, in <genexpr>(.0)
#       2 sufi_titles = ['Şeyh', 'Derviş', 'dede', 'baba', 'mevlevi', 'bektaşi', 'nakşibendi', 'halveti', 'Sufi', 'Sufi leader']
#       4 # Sufileri filtreleyin
# ----> 5 sufis = istanbul18[istanbul18['titles'].apply(lambda titles: any(title in titles for title in sufi_titles))]
#       7 # Sufilerin dahil oldukları dava türlerini hesaplayın
#       8 sufi_case_types = sufis['legal_case_type'].value_counts()
#
# TypeError: argument of type 'float' is not iterable
