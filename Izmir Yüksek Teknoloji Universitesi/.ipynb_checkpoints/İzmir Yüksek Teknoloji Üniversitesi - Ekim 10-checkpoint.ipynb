# %% [markdown]
# # İstanbul Kadı Sicillerinde Sufiler Bulmak: Yapay Zekâ Destekli Bir Araştırma

# %%
import pandas as pd
import os
import pathlib as Path
import matplotlib.pyplot as plt
import glob
import ast
import re

# %%
project_root = '/Users/ahmetyusufyuksek/Documents/GitHub/Sufism-and-Urban-Religiosity'
file_path = os.path.join(project_root, 'data', 'sicil_records.csv')
df = pd.read_csv(file_path)

# %%
df['case_text_summary'] = "Summary: " + df['case_summary'].astype(str) + "\n" + "Case: " + df['case_text'].astype(str)
df.head()
# Out:
#         court_title  sicil_number                    sicil_date    date_hijri  \
# 0  Adalar Mahkemesi             1  H. 1178-1184 / M. 1764-1771)  H. 1178-1184
# 1  Adalar Mahkemesi             1  H. 1178-1184 / M. 1764-1771)  H. 1178-1184
# 2  Adalar Mahkemesi             1  H. 1178-1184 / M. 1764-1771)  H. 1178-1184
# 3  Adalar Mahkemesi             1  H. 1178-1184 / M. 1764-1771)  H. 1178-1184
# 4  Adalar Mahkemesi             1  H. 1178-1184 / M. 1764-1771)  H. 1178-1184
#
#      date_miladi                                          case_text  \
# 0  M. 1764-1771)  ['[İç Kapak]', 'Mûcebince amel oluna deyü buyr...
# 1  M. 1764-1771)  ['Kasab Veli Beşe kanadârı Mumço? nâm zimmîye ...
# 2  M. 1764-1771)  ['Bundan akdem hâlik olan Esteban v. Kirkor v....
# 3  M. 1764-1771)  ['Culûs-ı Sultân Mustafa Han b. es-Sultân Abdü...
# 4  M. 1764-1771)  ['Devletlü inâyetlü merhametlü efendim sultânı...
#
#                                         case_summary  case_number  id  \
# 0                       117[8] ilâ 1184 Adalar Hücec   Hüküm no:    1
# 1               Kasap Veli’nin Mumço’ya kefil olduğu  Hüküm no: 1   2
# 2  Ölen Esteban’ın terekesinin varislerine taksim...  Hüküm no: 2   3
# 3  Sultan Mustafa Han’ın tahta çıkış tarihinin no...  Hüküm no: 3   4
# 4                      Yarım kalan bir arzuhal kaydı  Hüküm no: 4   5
#
#                                    case_text_summary
# 0  Summary: 117[8] ilâ 1184 Adalar Hücec\nCase: [...
# 1  Summary: Kasap Veli’nin Mumço’ya kefil olduğu\...
# 2  Summary: Ölen Esteban’ın terekesinin varisleri...
# 3  Summary: Sultan Mustafa Han’ın tahta çıkış tar...
# 4  Summary: Yarım kalan bir arzuhal kaydı\nCase: ...

# %%
# Farklı mahkeme sayısı
num_courts = df['court_title'].nunique()

# Her mahkeme için sicil sayısı (court_title ve sicil_number birleştirilerek)
registers_per_court = df.groupby('court_title')['sicil_number'].nunique()

# Her mahkeme için dava girişlerinin sayısı
case_entries_per_court = df.groupby('court_title').size()

# Toplam dava sayısı
total_cases = case_entries_per_court.sum()

# Sonuçları göster
print(f"Farklı mahkeme sayısı: {num_courts}")
print("Her mahkeme için sicil sayısı:")
print(registers_per_court)
print("Her mahkeme için dava girişlerinin sayısı:")
print(case_entries_per_court)
print(f"Toplam dava sayısı: {total_cases}")
total_registers = registers_per_court.sum()
print(f"Toplam sicil sayısı: {total_registers}")
# Out:
# Farklı mahkeme sayısı: 24
# Her mahkeme için sicil sayısı:
# court_title
# Adalar Mahkemesi                    1
# Ahi Çelebi Mahkemesi                1
# Anadolu Sadareti Mahkemesi          1
# Anadolu Sadâreti Mahkemesi          1
# Bab Mahkemesi                      10
# Balat Mahkemesi                     2
# Beşiktaş Mahkemesi                  2
# Davud Paşa Mahkemesi                1
# Evkaf Muhasebesi                    1
# Evkaf-ı Hümâyûn Mahkemesi           1
# Evkaf-ı Hümâyûn Müfettişliği        1
# Eyüb Mahkemesi (Havass-ı Refia)     8
# Eyüp Mahkemesi                      4
# Galata Mahkemesi                   12
# Hasköy Mahkemesi                    3
# Kartal Mahkemesi                    1
# Kısmet-i Askeriye Mahkemesi         2
# Mahfel-i Şer‘iyyât Mahkemesi        1
# Mahmudpaşa Mahkemesi                1
# Rumeli Sadareti Mahkemesi           3
# Rumeli Sadâreti Mahkemesi           5
# Tophane Mahkemesi                   1
# Üsküdar Mahkemesi                  13
# İstanbul Mahkemesi                 24
# Name: sicil_number, dtype: int64
# Her mahkeme için dava girişlerinin sayısı:
# court_title
# Adalar Mahkemesi                     183
# Ahi Çelebi Mahkemesi                 534
# Anadolu Sadareti Mahkemesi           185
# Anadolu Sadâreti Mahkemesi           254
# Bab Mahkemesi                       7245
# Balat Mahkemesi                     1115
# Beşiktaş Mahkemesi                  1027
# Davud Paşa Mahkemesi                 788
# Evkaf Muhasebesi                     283
# Evkaf-ı Hümâyûn Mahkemesi            239
# Evkaf-ı Hümâyûn Müfettişliği         586
# Eyüb Mahkemesi (Havass-ı Refia)     3718
# Eyüp Mahkemesi                      1862
# Galata Mahkemesi                    4895
# Hasköy Mahkemesi                    1190
# Kartal Mahkemesi                     491
# Kısmet-i Askeriye Mahkemesi         1293
# Mahfel-i Şer‘iyyât Mahkemesi         143
# Mahmudpaşa Mahkemesi                 572
# Rumeli Sadareti Mahkemesi            954
# Rumeli Sadâreti Mahkemesi           2833
# Tophane Mahkemesi                    894
# Üsküdar Mahkemesi                  11038
# İstanbul Mahkemesi                 12348
# dtype: int64
# Toplam dava sayısı: 54670
# Toplam sicil sayısı: 100

# %%
# Perform the specified changes in the DataFrame
df.loc[df['court_title'] == 'Evkaf Muhasebesi1', 'court_title'] = 'Evkaf Muhasebesi'
df.loc[df['court_title'] == 'Eyüb', 'court_title'] = 'Eyüp'
df.loc[df['court_title'] == 'Rumeli Sadâreti', 'court_title'] = 'Rumeli Sadareti'
df.loc[df['court_title'] == 'Evkaf-ı Hümâyûn', 'court_title'] = 'Evkaf Mahkemesi'
df.loc[df['court_title'] == 'Evkaf-ı HümâyûnMüfettişliği', 'court_title'] = 'Evkaf Müfettişliği'

df.loc[df['court_title'] == 'Evkaf Müfettişliği', 'sicil_number'] = '1'
df.loc[df['court_title'] == 'Evkaf Muhasebesi', 'sicil_number'] = '1'
df.loc[df['court_title'] == 'Evkaf Mahkemesi', 'sicil_number'] = '673'
# Out:
# /var/folders/54/1bt1zb4n7h7grgv919nm_0c00000gn/T/ipykernel_7393/2685030369.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['court_title'] == 'Evkaf Müfettişliği', 'sicil_number'] = '1'
